# %% [markdown]
# # Практическая работа №1: Основы анализа и моделирования социальных сетей
# Выполнила студентка гр. 0383 Ханина Мария. Вариант №19

# %% [markdown]
# ## Цель работы
# Овладеть навыками работы с математическими пакетами для моделирования, визуализации и анализа социальных сетей.

# %% [markdown]
# ## Основные теоретические положения
# <br>**Акторы**  -  дискретные индивидуальные, корпоративные или коллективные социальные единицы.
# <br>**Реляционная связь**  - свойство, описывающее взаимодействие между двумя акторами.
# <br>**Подгруппа** - любое подмножество акторов и все связи между ними.
# <br>**Группа** - совокупность всех акторов, связи между которыми должны быть изучены.
# <br>**Отношение** - совокупность связей определённого вида между членами группы.
# <br>**Социальная сеть** - объект, представляющий собой совокупность конечного набора акторов и отношений, определённых на них.
#
# <br><br>
# ### Типы представления сетей
#
# <br>Графовое
# <br>Социоматричное
# <br>Алгебраическое
#
# <br>
#
# ### Графовое:
# Граф - модель социальной сети с ненаправлеными дихроматическими отношениями, т.е. связь либо присутствует, либо отсутствует между кадой парой акторов:
#
# $\mathcal{G} = \mathcal{G}(\mathcal{N}, \mathcal{L})$
# <br>
# $\mathcal{N} = \{n_1, n_2, ..., n_g\}$ - набор узлов
# <br>
# $\mathcal{L} = \{l_1, l_2, ..., l_l\}$ - набор линий.
# <br><br>
# $l = <n_i, n_j>$ - направленная (ориентированная) связь.
# <br>
# $l = (n_i, n_j)$ - ненаправленная(неориентированная) связь.
# <br><br>
# **Подграф:** <br>
# Граф $\mathcal{G_s} = \mathcal{G_s}(\mathcal{N_s}, \mathcal{L_s})$ **называется подграфом графа** $\mathcal{G}(\mathcal{N}, \mathcal{L})$, **если** $\mathcal{N_s} ⊆ \mathcal{N}$ и $\mathcal{L_s} ⊆ \mathcal{L}$
# <br><br>
# <br>**Маршрут** - последовательность узлов и линий, начинающихся и заканчивающихся узлами, в которой каждый узел ициндентен линиям, следующим и предшевствующим ему в последовательности.
# <br>
# <br>**Тропа** - это маршрут, в котором все линии различны, однако некоторые узлы могут быть включены более одного раза.
# <br>**Путь** - это маршрут, все узлы и линии которого, различны.
#
# <br><br>
# ### Социометрическое:
# **Социоматрица** - матрица $\mathcal{X}$ размерности $\mathcal{g} \times  \mathcal{g}$, описывающая смежные узлы в сети:
# <br>$\mathcal{X} = \{\mathcal{X_{ij}, \mathcal{r}}\}$, где $\mathcal{i}, \mathcal{j} = 1, ..., \mathcal{g}$
# <br><br>**Матрица инцидентности** - матрица $\mathcal{I}$ размерности $\mathcal{g} \times \mathcal{L}$, описывающая какие линии каким узлам инцидентны.
# <br><br>
# **Матрица достижимости**: $\mathcal{X}^{\mathcal{[R]}} = \{\mathcal{X_{ij}}^{\mathcal{[R]}}\}$,
# <br>где $\mathcal{X_{ij}}^{\mathcal{[R]}} = 1_{\mathcal{X_{ij}}^{\mathcal{[Σ]}} \geq 1}$
# <br><br>
# ### Числовые характеристики сети:
#
# <br>Размер
# <br>Плотность
# <br>Компонента
# <br>Диаметр
# <br>Коэффициент кластеризации
#
# <br><br>
# **Размер** - количество акторов сети.
# <br><br>
# **Плотность** - доля имеющихся связей по отношению к максимально возможному количеству связей:
# <br>
# Для ор. сетей:<br><br>
# $Δ = \frac{L}{A_{g}^{2}}$, <br>где $L$ - количество связей.
# <br><br>
# Дла неор. сетей:<br><br>
# $Δ = \frac{L}{\begin{pmatrix}
# g\\
# 2
# \end{pmatrix}}$
# <br><br>
# **Компонента** - подгруппа, в которой все акторы связаны друг с другом прямо или косвенно.
# <br><br>
# **Диаметр полной сети** - наибольшая длина любого из кратчайших путей между всеми парами узлов.
# <br><br>
# **Степень узла** - число прямых, инцидентных узлу n (неор. граф).
# <br><br>
# Средняя степень узла:<br>
# $\mathcal{\overline{d}} = \frac{1}{g} ⋅ \sum_{i=1}^{g}{d(n_i)}$
# <br><br>Дисперсия степеней узлов:<br>
# $S_D^2 = \frac{1}{g} \cdot \sum_{i=1}^{g} {(d(n_i) - \overline{d})^2}$
# <br><br>
# Если d узла = 0, то узел называется "изолированным".
# <br><br>
# **Коэффициент кластеризации** $∈ [0,1]$ - доля закрытых треугольников (триад, где наблюдаются все свзяи) по отношению к общему количеству открытых и закрытых треугольников.
# <br><br>
# ## Укладка сетей
# Эстетический вид укладок сетей:
#
# <br>min пересечения рёбер
# <br>max симметричность укладки узлов
# <br>min изменчивость длины рёбер
# <br>max угол между рёбрами, когда они пересекают или соединяют узлы
# min общее пространство, использованное для вывода сети
# <br><br>
#
# ### Алгоритмы укладки сетей. Силовые алгоритмы:
#
# <br>**Алгоритм Идеса** - основан на механической модели (пружины).
# <br>**Алгоритм Фрюхтермана - Рейнольда** - основан на силе притяжения узлов - "атомных частиц" или "небесных тел".
# <br>**Алгоритм Татта** - На положение узлов графа виляют соседи (используется решение СЛАУ).
# <br>**Алгоритм Камада - Каваи** - Настройка пружинной системы таким образом, чтобы минимизация энергии системы соответствовала минимизации разницы между геометрическим и графовым расстояниям.
#
#
# <br><br>
# ## Меры важности
#
#
# **Центральность** - (centrality) мера, характеризующая актор с большим количеством связей (прямых или косвенных). [Для ненаправленных сетей]
# <br>
# Обозначение: $C_A(n_i)$, где $i = 1, ..., g$
# <br><br>
# **Престиж** - (presiege) мера, характеризующая актор с большим количеством входящих связей. [Для направленных сетей]
# <br>
# Обозначение $P_A(n_i)$, где $i = 1, ..., g$
# <br><br><br>
# **Централизация группы**
# <br><br>
# **Индекс центральности** (centralization index):
# <br>
# $C_A = \frac {\sum_{i=1}^{g}{[C_A(n^*) - C_A(n_i)}]} {max \sum_{i=1}^{g}{[C_A(n^*) - C_A(n_i)}]}$
# <br><br>
#
# <br>**Центральность по степени** (degree centrality) - степерь каждого актора
# <br>
# $C_D(n_i) = d(n_i)$
# <br>
# <br>
# <br>**Нормированная центральность по степени:**
# <br>
# $C_D^{'}(n_i) = \frac{d(n_i)}{g-1}$
# <br><br>
# <br>**Централизация по степени:**
# <br>
# $C_D = \frac {\sum_{i=1}^{g}{[C_D(n^*) - C_D(n_i)}]} {max \sum_{i=1}^{g}{[C_D(n^*) - C_D(n_i)}]} = \frac{\sum_{i=1}^{g}{[(C_D(n^*) - C_D(n_i)]}}{(g-1)(g-2)}$
# <br><br>
# <br>**Централизация по степеням:**
# <br>
# $S_D^2 = \frac{1}{g} \cdot \sum_{i=1}^{g}{(C_D(n_i) - \overline{C}_D^2}$
# <br><br><br>
# <br>**Центральность по близости** (closenss centrality) - более важными узлами сети считаются узлы наиболее близкие к остальным узлам сети:
# <br>
# $C_C(n_i) = (\sum_{i=1}^{g}{d(n_i,n_j)})^{-1}$ ,где $d(n_i, n_j)$ - расстояние между двумя узлами<br><br>
# <br>**Нормированная центральность по близости:**<br>
# $C_C^{'}(n_i) = \frac{g-1}{\sum_{i=1}^{g}{d(n_i, d_j)}} = (g-1)⋅C_C(n_i)$<br><br>
# <br>**Централизация по близости:**<br>
# $C_C = \frac{\sum_{i=1}^{g}{[(C_C(n^*) - C_C^{'}(n_i)]}}{(g-1)(g-2)/(2g-3)}$<br><br>
# <br> Можно использовать дисперсию:<br>
# $S_D^2 = \frac{1}{g}⋅\sum_{i=1}^{g}{(C_C^{'}(n_i) - \overline{C}_C)}$<br><br>
# <br>**Центральность по посредничеству** (betweeness centrality) - характеризует насколько важную роль данный узел играет на пути "между" парами других узлов сети, в том смысле, что пути между другими узлами должны проходить через данный узел:<br><br>
# $C_B(n_i) = \sum_{j<k}{g_{j,k}(n_i)/g_{jk}}$, где $g_{j,k}(n_i)$ - количество геодезических расстояний между узлами j и k, которые включают узел i<br>
# $g_{jk}$ - геодезическое расстояние между узлами j и k <br><br>
# <br>**Нормированная центральность по посредничеству:**<br>
# $C_B^{'}(n_i) = \frac{C_B(n_i)}{\begin{pmatrix}
# g-1\\
# 2
# \end{pmatrix}}$<br><br>
# <br>**Централизация по посредничеству:**<br>
# $C_B = \frac{2⋅\sum_{i=1}^{g}{[C_B(n^*) - C_B(n_i)]}}{(g-1)^2(g-1)} =
# \frac{\sum_{i=1}^{g}{[C_B^{'}(n^*) - C_B(n_i)]}}{g-1}$<br><br>
# <br>**Центральность по информации** - показывает сколько информации содержится в путях, которые начинаются (и заканчиваются) у определённого актора:<br>
# $C_I(n_i) = \frac{1}{C_{ii} + (T - 2R)/g}$, где $T = \sum_{i=1}^{g}{C_{ii}} = trC_i$, $R = \sum_{i=1}^{g}{C_{ij}}$<br><br>
# <br>**Нормированая центральность по информации:**<br>
# $C_{I}^{'}(n_i) = \frac{C_I(n_i)}{\sum_{j}{C_I(n_j)}}$
# Централизация по информации:<br>
# $S_i^2 = \frac{1}{g} ⋅ \sum_{i=1}^{g}{(C_I(n_i) - \overline{C}_I)^2}$, где $\overline{C}_I = \sum_{i}{C_i(n_i)}$
#
# <br><br><br>
# ### Престиж
# <br>
# **Престиж** (presiege) - мера, характеризующая актор с большим количеством входящих связей.
# <br><br>
#
#
# Престиж по степени (degree presitege) - входящая степень каждого узла.<br>
# $P_D(n_i) = d_i(n_i) = x_{+i}$<br><br>
# Нормированный престиж по степени:<br>
# $P_D^{'}(n_i) = \frac{x_{+i}}{g-1}$<br><br><br>
#
#
# Престиж по близости:<br><br>
# Область влияния актора (influence domain of actor) - $I_i$ - множество акторов, прямо и косвенно связанных с указаным актором.<br><br>
# Престиж по близости (proximity priestige) - определяет на сколько все акторы близки к заданному по расстоянию до него<br><br>
# Престиж по близости определяется как:<br>
# $P_P(n_i) = \frac{\#I_i / (g-1)} {\sum_{j⋅n ∈ I_i}{d(n_i, n_j)/\#I_i}}$, где $d(n_j, n_i)$ - расстояние пути между двумя узлами<br><br><br>
#
# **Престиж по близости для групп:**<br><br>
# Используется дисперсия:<br>
# $S_P^2 = \frac{1}{g} ⋅ \sum{(P_P(n_i) - \overline{P}_P)^2}$, где $\overline{P}_P = \frac{1}{g} ⋅ \sum_{i=1}^{g}{P_P(n_i)}$
#
# <br><br>
#
# <br>
#
# **Точки сочленения (cutpoint)** - узел, при удалении которого увеличивается количество компонент связности.
#
# **Мост (bridge)** - ребро, при удалении которого одна компонента связности разделяется на 2.
#
# **Подгруппа (subgroup)** - подмножество узлов: $\mathcal{N_S} ⊆ \mathcal{N}$, графа $\mathcal{G}(\mathcal{N}, \mathcal{L})$
#
# **Сплочённые подгруппы (social subgroup)** - множество акторов, которые соединены между собой посредствам многочисленных, сильных и прямых связей.
#
# **Клика (clique)** - максимальный полный подграф из 3х и более узлов
#
# **$n$-клика ($n$-clique)** - максимальный подграф, в котором наибольшее геодезическое расстояние между любыми двумя узлами не превышает $n$.
#
# **$n$-кланы ($n$-clans)** - n-клики, в которых геодезические расстояния $d(i,j)$ между всеми узлами в подграфе не превышает $n$ для путей внутри подграфа.
#
# **$n$-клубы ($n$-clubs)** - максимальный подграф диаметра $\leq n$.
#
# **$k$-ядро ($k$-core)** - максимальный подграф, в котором каждая вершина связана с минимум $k$ другими вершинами этого же подграфа.<br><br>
# Свойства $k$-ядер:
#   <br> Вложенные
#   <br> Не перекрываются
#   <br> Лекго определить

# %% [markdown]
# ## Постановка задачи
# С помощью математических пакетов и соответствующих библиотек провести анализ заданных социальных сетей вычислить описательные характеристики. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы
# 1. Из файла florentine_business.csv извлечь социоматрицу с помощью соответствующих функций. Вывести полученную социоматрицу на экран.

# %%
install.packages("statnet")
install.packages("devtools")
install.packages("igraph")
install.packages("network")
library(devtools)
library(statnet)
library(network)
library(igraph)
matr <- read.table("florentine_business.csv", header=TRUE, sep = ',')
rownames(matr) <- colnames(matr)
print(matr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘textshaping’, ‘ragg’, ‘pkgdown’
#
#
# Warning message in install.packages("devtools"):
# “installation of package ‘textshaping’ had non-zero exit status”
# Warning message in install.packages("devtools"):
# “installation of package ‘ragg’ had non-zero exit status”
# Warning message in install.packages("devtools"):
# “installation of package ‘pkgdown’ had non-zero exit status”
# Warning message in install.packages("devtools"):
# “installation of package ‘devtools’ had non-zero exit status”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#              Acciaiuoli Albizzi Barbadori Bischeri Castellani Ginori Guadagni
# ...

# %% [markdown]
# 2. Преобразовать социоматрицу в список рёбер. Вывести первые 5 элементов списка рёбер.

# %%
tmp <- data.frame(matr)
net.matrix <- data.matrix(tmp)
elem <- get.edgelist(graph.adjacency(net.matrix))
elem <- as_data_frame(simplify(graph_from_data_frame(elem, directed=FALSE)))
print(elem[c(1:5), c(1:2)])
# Out:
#        from         to
# 1 Barbadori Castellani
# 2 Barbadori     Ginori
# 3 Barbadori     Medici
# 4 Barbadori    Peruzzi
# 5  Bischeri   Guadagni

# %% [markdown]
# 3. Присвоить имена столбцам и строкам социоматрицы (имена – первая строка в csv-файле после комментариев).

# %%
print(net.matrix)
# Out:
#              Acciaiuoli Albizzi Barbadori Bischeri Castellani Ginori Guadagni
# Acciaiuoli            0       0         0        0          0      0        0
# Albizzi               0       0         0        0          0      0        0
# Barbadori             0       0         0        0          1      1        0
# Bischeri              0       0         0        0          0      0        1
# Castellani            0       0         1        0          0      0        0
# Ginori                0       0         1        0          0      0        0
# Guadagni              0       0         0        1          0      0        0
# Lamberteschi          0       0         0        1          1      0        1
# Medici                0       0         1        0          0      1        0
# Pazzi                 0       0         0        0          0      0        0
# Peruzzi               0       0         1        1          1      0        0
# ...

# %% [markdown]
# 4. С помощью соответствующих функций по полученной социоматрице построить ненаправленную сеть. Объяснить параметры, передаваемые в функцию. <br>
# В функцию передается социоматрица, полученная выше и требуемое направление - "undirected".

# %%
undnet <- graph_from_adjacency_matrix(net.matrix, mode = "undirected")
plot(undnet)
# Out:
# Plot with title “”

# %% [markdown]
# 5. Отобразить сеть с помощью алгоритмов укладки Фрюхтермана– Рейнгольда и Камада–Каваи. Объяснить, в чём различие между алгоритмами и укладками.
# <br>
# Алгоритм Фрюхтермана–Рейнгольда

# %%
dots <- layout_with_fr(undnet)
plot(undnet, layout=dots, vertex.size=50, edge.width = 6, rescale=FALSE,
      xlim=range(dots[,1]), ylim=range(dots[,2]), vertex.label.dist=0,
      vertex.label.color="blue", vertex.color = "white", edge.color = "green")
# Out:
# Plot with title “”

# %% [markdown]
#  Алгоритм Камада–Каваи

# %%
dots <- layout_with_kk(undnet)
plot(undnet, layout=dots, vertex.size=30, edge.width = 2, rescale=FALSE,
      xlim=range(dots[,1]), ylim=range(dots[,2]), vertex.label.dist=0,
      vertex.label.color="blue", vertex.color = "white", edge.color = "green")
# Out:
# Plot with title “”

# %% [markdown]
#   Разница в алгоритмах заключается в том, что алгоритм Камада–Каваи итеративно формирует функции энергии и находит ее минимум, в то время как алгоритм Фрюхтермана–Рейнгольда итеративно применяет силы. Сходство в том, что оба алгоритма силовые и ищут баланс сил. <br> В данном случае, раскладки практически одинаковы.

# %% [markdown]
# 6. Вывести «описательную сводку» сети.

# %%
tmp <- as.network(x = net.matrix, directed = F, loops = F, matrix.type = "adjacency")
summary(tmp)
# Out:
# Network attributes:
#   vertices = 16
#   directed = FALSE
#   hyper = FALSE
#   loops = FALSE
#   multiple = FALSE
#   bipartite = FALSE
#  total edges = 15
#    missing edges = 0
#    non-missing edges = 15
#  density = 0.125
#
# Vertex attributes:
#   vertex.names:
#    character valued attribute
#    16 valid vertex names
#
# No edge attributes
#
# Network edgelist matrix:
#       [,1] [,2]
#  [1,]    5    3
#  [2,]    6    3
#  [3,]    9    3
#  [4,]   11    3
#  [5,]    7    4
#  [6,]    8    4
#  [7,]   11    4
#  [8,]    8    5
#  [9,]   11    5
# [10,]    9    6
# [11,]    8    7
# [12,]   11    8
# [13,]   10    9
# [14,]   14    9
# [15,]   16    9

# %% [markdown]
# 7. Вычислить «пятичисловую сводку» сети: <br>(a) Вычислить размер сети.  <br>(b) Вычислить плотность сети вручную и с помощью соответствующей функции. Сделать выводы.  <br>(c) Определить число компонент в сети по графику. Подтвердить свои догадки с помощью соответствующей функции. Сделать выводы.  <br>(d) Вычислить диаметр сети. Сделать выводы  <br>(e) Вычислить коэффициент кластеризации. Сделать выводы.

# %%
#a
print(vcount(undnet))
#b1
print(edge_density(undnet))
#b2
print(nrow(edges)/(ncol(net.matrix)*(ncol(net.matrix)-1)/2))
#c
print(count_components(undnet))
#d
print(diameter(undnet, directed = F))
#e
print(transitivity(undnet))
# Out:
# [1] 16
# [1] 0.125
# numeric(0)
# [1] 6
# [1] 5
# [1] 0.4166667

# %% [markdown]
# a) Размер сети - это количество вершин, то есть 16
# <br>
# b)Плотность - это доля имеющихся связей к числу возможных связей. Чем оно ближе к единице, тем взаимосвязаннее сеть. Для данной сети значение далеко от единицы, следовательно, сеть не сильно взаимосвязанная.
# <br>
# c)По графику сети из 5 задания можно было заметить 6 групп, следовательно, количество компонент 6
# <br>
# d)Диаметр - наибольший кратчайший путь между всеми парами узлов. Если сеть состоит из нескольких компонент, исследуем самую большую. Наибольший кратчайший путь из одной вершины в другую - 5, если смотреть на график. Ответ с выводом функции совпал
# <br>
# e)Доля закрытых треугольников к общему числу открытых и закрытых треугольников. Значение колеблется от до 1, полученное значение для этой сети можно охарактеризовать как умеренное, среднее

# %% [markdown]
# 8. Вычислить среднюю степень узлов и дисперсию. Сделать выводы.

# %%
#Cредняя степень узлов
average.deg <- sum(igraph::degree(undnet))/nrow(net.matrix)
print(average.deg) 
#Дисперсия
print(sum((igraph::degree(undnet)-average.deg)^2)/nrow(net.matrix))
# Out:
# [1] 1.875
# [1] 2.859375

# %% [markdown]
# Количество связей в сети неравмномерное, так как среднее значение близко к 2, однако среднеквадратичное отклонение велико. Это видно на графе: есть 5 изолированных вершин и вершины, у которых связей больше, чем 2.

# %% [markdown]
# 9. Заполнить таблицу для различных мер центральности. Примеча-
# ние: меры центральности вычислить для неизолированных вершин:
# 𝑛𝑖 𝐶′
# 𝐷(𝑛𝑖) 𝐶′
# 𝐶 (𝑛𝑖) 𝐶′
# 𝐵 (𝑛𝑖) 𝐶′
# 𝐼 (𝑛𝑖)
# Сделать выводы.

# %%
del <- which(igraph::degree(undnet)==0)
connected.graph <- igraph::delete.vertices(undnet, del)
vertexes <- igraph::get.vertex.attribute(connected.graph)
vertexes$color <- NULL
centr.degr <- igraph::degree(connected.graph, normalized = T)
centr.close <- igraph::closeness(connected.graph, normalized = T)
centr.between <- igraph::betweenness(connected.graph, normalized = T)
centr.inform <- infocent(as.matrix(as_adjacency_matrix(connected.graph)), rescale=TRUE)
centr.df <- data.frame(vertexes, centr.degr, centr.close, centr.between, centr.inform)
rownames(centr.df) <- NULL
print(centr.df)
# Out:
#            name centr.degr centr.close centr.between centr.inform
# 1     Barbadori        0.4   0.5882353    0.55555556   0.12446815
# 2      Bischeri        0.3   0.4000000    0.05555556   0.08898359
# 3    Castellani        0.3   0.5000000    0.11111111   0.10457651
# 4        Ginori        0.2   0.4545455    0.00000000   0.09531249
# 5      Guadagni        0.2   0.3125000    0.00000000   0.07656303
# 6  Lamberteschi        0.4   0.4166667    0.13333333   0.09837087
# 7        Medici        0.5   0.5263158    0.53333333   0.11089878
# 8         Pazzi        0.1   0.3571429    0.00000000   0.06388631
# 9       Peruzzi        0.4   0.5263158    0.30000000   0.10916767
# 10     Salviati        0.1   0.3571429    0.00000000   0.06388631
# 11   Tornabuoni        0.1   0.3571429    0.00000000   0.06388631

# %% [markdown]
# Самые важные акторы: <br>
# По степени: Medici<br>
# По близости: Barbadory<br>
# По поредничеству: Barbadory<br>
# По информации: Barbadory<br>
#
# Из этого можно сделать вывод о том, что выбор меры центральности зависит от конкретного требования.

# %% [markdown]
# 10. Вычислить значение централизации для каждой меры. Сделать выводы.

# %%
centr.close.res <- centr_clo(connected.graph)[2]
centr.between.res <- centr_betw(connected.graph)[2]
centr.degr.res <- centr_degree(connected.graph)[2]
centr.inform.res <- (1/vcount(connected.graph)) * sum((centr.inform - sum(centr.inform))^2)
print(centr.inform.res)
print(centr.degr.res)
print(centr.between.res)
print(centr.close.res)
# Out:
# [1] 0.8268573
# $centralization
# [1] 0.2272727
#
# $centralization
# [1] 0.4422222
#
# $centralization
# [1] 0.3535226

# %% [markdown]
#  Все полученные значения различны, значит выбор централизации также зависит от конкретной задачи

# %% [markdown]
# 11. Выявить точки сочленения и мосты сети. Подтвердить свои догад- ки с помощью соответствующих функций (если их нет – реализуйте их самостоятельно). Построить график сети, на котором выделены точки сочленения и мосты.

# %%
print(articulation.points(undnet))
print(bridges(undnet))
V(undnet)$color <- "white"
V(undnet)$color[ articulation.points(undnet) ] <- "green"
E(undnet)$color <- "black"
E(undnet)$color[bridges(undnet)] <- "red"

plot(undnet, layout = layout.fruchterman.reingold, vertex.label = V(undnet)$name, vertex.size = 30, vertex.color= V(undnet)$color, 
vertex.frame.color= "black", vertex.label.color = "black", edge.width=6, edge.color=E(undnet)$color)
# Out:
# + 2/16 vertices, named, from 3528d83:
# [1] Medici    Barbadori
# + 3/15 edges from 3528d83 (vertex names):
# [1] Medici--Pazzi      Medici--Salviati   Medici--Tornabuoni
# Plot with title “”

# %% [markdown]
# Рассмотрим наибольшую компоненту связности, можно заметить три вершины с одной связью: Pazzi, Salviary, Tomabuoni. Все они соединены с Medici. Если убрать эти три ребра, то получится три новые компоненты связности, следовательно, каждое из этих ребер является мостом. Вершина Medici является точкой сочленения, так как если ее убрать, то появятся эти же новые компоненты связности. Также точкой сочленения является Barbadory.

# %% [markdown]
# 12. Выполнить пп. 2–8 для направленной сети из файла krackhardt_advice.csv.

# %%
matr2 <- read.table("krackhardt_advice.csv", header=FALSE, sep = ',')
rownames(matr2) <- colnames(matr2)
tmp <- data.frame(matr2)
net2.matrix <- data.matrix(tmp)
elem2 <- get.edgelist(graph.adjacency(net2.matrix))
elem2 <- as_data_frame(simplify(graph_from_data_frame(elem2, directed=FALSE)))
print(elem2[c(1:5), c(1:2)])
# Out:
#   from to
# 1   V1 V2
# 2   V1 V3
# 3   V1 V4
# 4   V1 V5
# 5   V1 V8

# %% [markdown]
# В функцию передается социоматрица, полученная выше и требуемое направление - "directed".

# %%
undnet2 <- graph_from_adjacency_matrix(net2.matrix, mode = "directed")
plot(undnet2)
# Out:
# Plot with title “”

# %% [markdown]
# Алгоритм Фрюхтермана–Рейнгольда:

# %%
dots2 <- layout_with_fr(undnet2)
plot(undnet2, layout=dots2, vertex.size=20, edge.width = 6, rescale=FALSE,
      xlim=range(dots2[,1]), ylim=range(dots2[,2]), vertex.label.dist=0,
      vertex.label.color="blue", vertex.color = "white", edge.color = "pink")
# Out:
# Plot with title “”

# %% [markdown]
# Алгоритм Камада-Каваи:

# %%
dots2 <- layout_with_kk(undnet2)
plot(undnet2, layout=dots2, vertex.size=20, edge.width = 6, rescale=FALSE,
      xlim=range(dots2[,1]), ylim=range(dots2[,2]), vertex.label.dist=0,
      vertex.label.color="blue", vertex.color = "white", edge.color = "pink")
# Out:
# Plot with title “”

# %% [markdown]
# В алгоритме Фрюхтермана–Рейнгольда вершины расположены более равномерно чем в алгоритме Камада-Каваи, в котором вершины расположились по кругу.

# %% [markdown]
# Вывод «описательной сводки» сети.

# %%
tmp <- as.network(x = net2.matrix, directed = F, loops = F, matrix.type = "adjacency")
summary(tmp)
# Out:
# Network attributes:
#   vertices = 21
#   directed = FALSE
#   hyper = FALSE
#   loops = FALSE
#   multiple = FALSE
#   bipartite = FALSE
#  total edges = 145
#    missing edges = 0
#    non-missing edges = 145
#  density = 0.6904762
#
# Vertex attributes:
#   vertex.names:
#    character valued attribute
#    21 valid vertex names
#
# No edge attributes
#
# Network edgelist matrix:
#        [,1] [,2]
#   [1,]    2    1
#   [2,]    3    1
#   [3,]    4    1
#   [4,]    5    1
#   [5,]    8    1
#   [6,]    9    1
#   [7,]   10    1
#   [8,]   11    1
#   [9,]   13    1
#  [10,]   15    1
#  [11,]   16    1
#  [12,]   17    1
#  [13,]   18    1
#  [14,]   19    1
#  [15,]   20    1
#  [16,]   21    1
#  [17,]    3    2
#  [18,]    4    2
#  [19,]    5    2
#  [20,]    6    2
#  [21,]    7    2
#  [22,]    8    2
#  [23,]    9    2
#  [24,]   10    2
#  [25,]   11    2
#  [26,]   13    2
#  [27,]   14    2
#  [28,]   15    2
#  [29,]   16    2
#  [30,]   17    2
#  [31,]   18    2
# ...

# %% [markdown]
# Вычислить «пятичисловую сводку» сети:
# (a) Вычислить размер сети.
# (b) Вычислить плотность сети вручную и с помощью соответствующей функции. Сделать выводы.
# (c) Определить число компонент в сети по графику. Подтвердить свои догадки с помощью соответствующей функции. Сделать выводы.
# (d) Вычислить диаметр сети. Сделать выводы
# (e) Вычислить коэффициент кластеризации. Сделать выводы.

# %%
#a
print(vcount(undnet2))
#b1
print(edge_density(undnet2))
#b2
print(nrow(edges)/(ncol(net2.matrix)*(ncol(net2.matrix)-1)/2))
#c
print(count_components(undnet2))
#d
print(diameter(undnet2, directed = F))
#e
print(transitivity(undnet2))
# Out:
# [1] 21
# [1] 0.452381
# numeric(0)
# [1] 1
# [1] 2
# [1] 0.7345088

# %% [markdown]
# a) Размер сети - это количество вершин, то есть 21. <br>
# b)Плотность - это доля имеющихся связей к числу возможных связей. Чем оно ближе к единице, тем взаимосвязаннее сеть. Для данной сети значение ближе к единице, следовательно, сеть более взаимосвязана, чем первая. <br>
# c)В сети одна большая компомента всязности. <br>
# d)Диаметр - наибольший кратчайший путь между всеми парами узлов. Если сеть состоит из нескольких компонент, исследуем самую большую. Наибольший кратчайший путь из одной вершины в другую - 2. Ответ с выводом функции совпал. <br>
# e)Доля закрытых треугольников к общему числу открытых и закрытых треугольников. Значение колеблется от до 1, полученное значение для этой сети можно охарактеризовать как умеренное.

# %% [markdown]
# Вычислим среднюю степень узлов и дисперсию.

# %%
#Cредняя степень узлов
average.deg <- sum(igraph::degree(undnet2))/nrow(net2.matrix)
print(average.deg) 
#Дисперсия
print(sum((igraph::degree(undnet2)-average.deg)^2)/nrow(net2.matrix))
# Out:
# [1] 18.09524
# [1] 30.6576

# %% [markdown]
# ## Выводы
#
# Практическая работа была выполнена на языке R. В результате были получены навыки работы с математическими пакетами, умение анализировать и моделировать социальные сети на языке R. Были построены две сети: "Business relation between Florentine families" (неориентированная сеть) и "Advice relation between managers of Krackhardt's high-tech company" (ориентированная сеть). Для каждой сети был проведен анализ, полученные результаты были отражены в отчете. Также были изучены и использованы для построения обеих сетей алгоритмы укладки Фрюхтермана–Рейнгольда и Камада–Каваи.
